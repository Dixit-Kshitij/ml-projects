# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DailyDelhiClimateTest.csv')

# %%
df
# Out:
#            date   meantemp
# 0    2017-01-01  15.993428
# 1    2017-01-02  14.900463
# 2    2017-01-03  16.649359
# 3    2017-01-04  18.577033
# 4    2017-01-05  15.239658
# ..          ...        ...
# 109  2017-04-20  34.143144
# 110  2017-04-21  30.631484
# 111  2017-04-22  34.592990
# 112  2017-04-23  34.943469
# 113  2017-04-24  39.926484
#
# [114 rows x 2 columns]

# %%
plt.scatter(df['date'],df['meantemp'])

# %%
x1 = df['meantemp'].ewm(alpha=0.9).mean()

# %%
x1
# Out:
# 0      15.993428
# 1      14.999823
# 2      16.485892
# 3      18.368107
# 4      15.552475
#          ...
# 109    34.191332
# 110    30.987469
# 111    34.232438
# 112    34.872366
# 113    39.421072
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewma'] = x1

# %%
# plt.figure()
plt.scatter(df['date'],df['meantemp'])
plt.scatter(df['date'],df['ewma'])
