# %%
import seaborn as sns
import pandas as pd
from scipy.stats import f_oneway

# %%
df = sns.load_dataset('titanic')

# %%
df[['age','pclass']].isnull().sum()
# Out:
# age       177
# pclass      0
# dtype: int64

# %%
df = df[['age','pclass']].dropna()

# %%
class_1 = df[df['pclass']==1]['age']
class_2 = df[df['pclass']==2]['age']
class_3 = df[df['pclass']==3]['age']

# %%
df.head()
# Out:
#     age  pclass
# 0  22.0       3
# 1  38.0       1
# 2  26.0       3
# 3  35.0       1
# 4  35.0       3

# %%
f_stats,p_value = f_oneway(class_1,class_2,class_3)

# %%
alpha = 0.05

# %%
f_stats
# Out:
# 57.443484340676214

# %%
p_value
# Out:
# 7.487984171959904e-24

# %%
if p_value < alpha:
    print('we reject null hypothesis thus significant relationship exists')
else:
    print('there is no significant difference')
# Out:
# we reject null hypothesis thus significant relationship exists

# %%
class_1
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 11     58.0
# 23     28.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: age, Length: 186, dtype: float64

# %%
df
# Out:
#       age  pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 885  39.0       3
# 886  27.0       2
# 887  19.0       1
# 889  26.0       1
# 890  32.0       3
#
# [714 rows x 2 columns]
